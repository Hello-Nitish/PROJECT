# %%
import os
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray
import cv2

# %%
kajol = os.listdir("/content/contents/kajol/kajol Face")

# %%
keerthy = os.listdir("/content/contents/keerthy/keerthy_suresh_Face")

# %%
arm = os.listdir("/content/contents/arm/ana de armas face")

# %%
limit = 50
kajol_images = [None]*limit
j=0
for i in kajol:
    if (j<limit):
        kajol_images[j] = imread("/content/contents/kajol/kajol Face/"+i)
        j+=1
    else:
        break

# %%
limit = 50
arm_images = [None]*limit
j=0
for i in arm:
    if (j<limit):
        arm_images[j] = imread("/content/contents/arm/ana de armas face/"+i)
        j+=1
    else:
        break

# %%
imshow(kajol_images[19])

# %%
limit = 50
keerthy_images = [None]*limit
j=0
for i in keerthy:
    if (j<limit):
        keerthy_images[j] = imread("/content/contents/keerthy/keerthy_suresh_Face/"+i)
        j+=1
    else:
        break

# %%
imshow(keerthy_images[45])

# %%
imshow(arm_images[5])

# %%
limit = 50
keerthy_gray = [None]*limit
j = 0

for i in keerthy:
    if(j<limit):
        keerthy_gray[j] = rgb2gray(keerthy_images[j])
        j = j+1
    else:
        break

# %%
imshow(keerthy_gray[2])

# %%
limit = 50
kajol_gray = [None]*limit
j = 0

for i in keerthy:
    if(j<limit):
        kajol_gray[j] = rgb2gray(kajol_images[j])
        j = j+1
    else:
        break

# %%
imshow(kajol_gray[2])

# %%
limit = 50
arm_gray = [None]*limit
j = 0

for i in arm:
    if(j<limit):
        arm_gray[j] = rgb2gray(arm_images[j])
        j = j+1
    else:
        break

# %%
imshow(arm_gray[2])

# %%
for j in range(50):
    kajol =  kajol_gray[j]
    kajol_gray[j]=resize(kajol, (500,500))

# %%
imshow(kajol_gray[11])

# %%
print(len(kajol_gray))
# Out:
# 50

# %%
kajol_gray[11].shape
# Out:
# (500, 500)

# %%
len_of_images_kajol=len(kajol_gray)

# %%
image_size_kajol=kajol_gray[11].shape
image_size_kajol
# Out:
# (500, 500)

# %%
flatten_size_kajol=image_size_kajol[0]*image_size_kajol[1]
flatten_size_kajol
# Out:
# 250000

# %%
for i in range(len_of_images_kajol):
    kajol_gray[i] = np.ndarray.flatten(kajol_gray[i]).reshape(flatten_size_kajol,1)

# %%
kajol_gray = np.dstack(kajol_gray)

# %%
kajol_gray = np.rollaxis(kajol_gray, axis=2, start=0)
kajol_gray.shape
# Out:
# (50, 250000, 1)

# %%
kajol_gray = kajol_gray.reshape(len_of_images_kajol, flatten_size_kajol)
kajol_gray.shape
# Out:
# (50, 250000)

# %%
kajoldf = pd.DataFrame(kajol_gray)
kajoldf
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.471366  0.471366  0.471366  0.471366  0.472209  0.475420  0.478833
# 1   0.501282  0.501282  0.501282  0.501282  0.501282  0.501282  0.501286
# 2   0.747047  0.747047  0.750969  0.750969  0.750969  0.750969  0.750969
# 3   0.653936  0.702739  0.662695  0.615319  0.655906  0.659641  0.651008
# 4   0.827315  0.827342  0.821850  0.811604  0.799822  0.796769  0.803414
# 5   0.612225  0.610347  0.607978  0.616002  0.621988  0.626339  0.623204
# 6   0.631335  0.638556  0.650482  0.658138  0.669190  0.681234  0.684063
# 7   0.170341  0.074879  0.060792  0.059671  0.057202  0.074741  0.071617
# 8   0.011765  0.011765  0.011765  0.011765  0.011765  0.011765  0.011765
# 9   0.916604  0.916604  0.916604  0.916604  0.916604  0.916604  0.916209
# 10  0.109371  0.127367  0.140815  0.134499  0.119198  0.119349  0.131822
# 11  0.426164  0.430869  0.435171  0.434183  0.426627  0.421011  0.409335
# ...

# %%
kajoldf["label"] = "kajol"
kajoldf
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.471366  0.471366  0.471366  0.471366  0.472209  0.475420  0.478833
# 1   0.501282  0.501282  0.501282  0.501282  0.501282  0.501282  0.501286
# 2   0.747047  0.747047  0.750969  0.750969  0.750969  0.750969  0.750969
# 3   0.653936  0.702739  0.662695  0.615319  0.655906  0.659641  0.651008
# 4   0.827315  0.827342  0.821850  0.811604  0.799822  0.796769  0.803414
# 5   0.612225  0.610347  0.607978  0.616002  0.621988  0.626339  0.623204
# 6   0.631335  0.638556  0.650482  0.658138  0.669190  0.681234  0.684063
# 7   0.170341  0.074879  0.060792  0.059671  0.057202  0.074741  0.071617
# 8   0.011765  0.011765  0.011765  0.011765  0.011765  0.011765  0.011765
# 9   0.916604  0.916604  0.916604  0.916604  0.916604  0.916604  0.916209
# 10  0.109371  0.127367  0.140815  0.134499  0.119198  0.119349  0.131822
# 11  0.426164  0.430869  0.435171  0.434183  0.426627  0.421011  0.409335
# ...

# %%
for j in range(50):
    arm =  arm_gray[j]
    arm_gray[j]=resize(arm, (500,500))

# %%
print(len(arm_gray))
# Out:
# 50

# %%
arm_gray[6].shape
# Out:
# (500, 500)

# %%
len_of_images_arm=len(arm_gray)

# %%
image_size_arm=arm_gray[6].shape
image_size_arm
# Out:
# (500, 500)

# %%
flatten_size_arm=image_size_arm[0]*image_size_arm[1]
flatten_size_arm
# Out:
# 250000

# %%
for i in range(len_of_images_arm):
    arm_gray[i] = np.ndarray.flatten(arm_gray[i]).reshape(flatten_size_arm,1)

# %%
arm_gray = np.dstack(arm_gray)

# %%
arm_gray = np.rollaxis(arm_gray, axis=2, start=0)
arm_gray.shape
# Out:
# (50, 250000, 1)

# %%
arm_gray = arm_gray.reshape(len_of_images_arm, flatten_size_arm)
arm_gray.shape
# Out:
# (50, 250000)

# %%
armdf = pd.DataFrame(arm_gray)
armdf
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.706262  0.703467  0.701730  0.695967  0.694421  0.695753  0.699070
# 1   0.180387  0.185503  0.189912  0.189776  0.183822  0.173061  0.176827
# 2   0.042869  0.042869  0.042869  0.042869  0.042869  0.042869  0.042869
# 3   0.849472  0.871686  0.870703  0.869591  0.870599  0.862015  0.861939
# 4   0.055527  0.055323  0.053876  0.052987  0.052324  0.050992  0.049545
# 5   0.140308  0.149713  0.124808  0.114147  0.145889  0.142747  0.139878
# 6   0.338239  0.338239  0.338239  0.340984  0.342160  0.342160  0.343337
# 7   0.434982  0.443362  0.449166  0.437776  0.445506  0.434656  0.433961
# 8   0.941949  0.538466  0.442855  0.440706  0.440951  0.438329  0.436794
# 9   0.823738  0.835182  0.833255  0.827414  0.830282  0.826888  0.822079
# 10  0.763081  0.768888  0.719942  0.668990  0.613816  0.563330  0.531204
# 11  0.399101  0.413755  0.425129  0.434569  0.446648  0.457739  0.463317
# ...

# %%
armdf["label"] = "arm"
armdf
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.706262  0.703467  0.701730  0.695967  0.694421  0.695753  0.699070
# 1   0.180387  0.185503  0.189912  0.189776  0.183822  0.173061  0.176827
# 2   0.042869  0.042869  0.042869  0.042869  0.042869  0.042869  0.042869
# 3   0.849472  0.871686  0.870703  0.869591  0.870599  0.862015  0.861939
# 4   0.055527  0.055323  0.053876  0.052987  0.052324  0.050992  0.049545
# 5   0.140308  0.149713  0.124808  0.114147  0.145889  0.142747  0.139878
# 6   0.338239  0.338239  0.338239  0.340984  0.342160  0.342160  0.343337
# 7   0.434982  0.443362  0.449166  0.437776  0.445506  0.434656  0.433961
# 8   0.941949  0.538466  0.442855  0.440706  0.440951  0.438329  0.436794
# 9   0.823738  0.835182  0.833255  0.827414  0.830282  0.826888  0.822079
# 10  0.763081  0.768888  0.719942  0.668990  0.613816  0.563330  0.531204
# 11  0.399101  0.413755  0.425129  0.434569  0.446648  0.457739  0.463317
# ...

# %%
for j in range(50):
    keerthy =  keerthy_gray[j]
    keerthy_gray[j]=resize(keerthy, (500,500))

# %%
print(len(keerthy_gray))
# Out:
# 50

# %%
keerthy_gray[6].shape
# Out:
# (500, 500)

# %%
len_of_images_keerthy=len(keerthy_gray)

# %%
image_size_keerthy=keerthy_gray[6].shape
image_size_keerthy
# Out:
# (500, 500)

# %%
flatten_size_keerthy=image_size_keerthy[0]*image_size_keerthy[1]
flatten_size_keerthy
# Out:
# 250000

# %%
for i in range(len_of_images_keerthy):
    keerthy_gray[i] = np.ndarray.flatten(keerthy_gray[i]).reshape(flatten_size_keerthy,1)

# %%
keerthy_gray = np.dstack(keerthy_gray)

# %%
keerthy_gray = np.rollaxis(keerthy_gray, axis=2, start=0)
keerthy_gray.shape
# Out:
# (50, 250000, 1)

# %%
keerthy_gray = keerthy_gray.reshape(len_of_images_keerthy, flatten_size_keerthy)
keerthy_gray.shape
# Out:
# (50, 250000)

# %%
keerthydf = pd.DataFrame(keerthy_gray)
keerthydf
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.853494  0.853494  0.854283  0.857553  0.857582  0.852858  0.849923
# 1   0.035704  0.032766  0.037666  0.043548  0.043549  0.048392  0.050351
# 2   0.099967  0.099967  0.099967  0.099967  0.099967  0.099967  0.099967
# 3   0.277149  0.279859  0.280830  0.280964  0.277996  0.276196  0.273715
# 4   0.235567  0.232317  0.229713  0.230021  0.226525  0.223592  0.225767
# 5   0.135823  0.118500  0.114270  0.121762  0.115281  0.113729  0.118567
# 6   0.079792  0.079792  0.079792  0.079792  0.080460  0.083704  0.083713
# 7   0.036686  0.036686  0.036682  0.034774  0.032769  0.032764  0.032764
# 8   0.311022  0.311262  0.313859  0.312796  0.313005  0.314869  0.316362
# 9   0.876154  0.876154  0.876154  0.876154  0.876154  0.876154  0.876154
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.505954  0.515855  0.504646  0.491052  0.487316  0.465365  0.440790
# ...

# %%
keerthydf["label"] = "keerthy"
keerthydf
# Out:
#            0         1         2         3         4         5         6  \
# 0   0
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.815111  0.816146  0.818533  0.818898  0.819776  0.821184  0.823517
# 1    0.798554  0.796151  0.793686  0.793048  0.795226  0.797753  0.803351
# 2    0.093933  0.170337  0.161907  0.106898  0.104774  0.161395  0.163330
# 3    0.827315  0.827342  0.821850  0.811604  0.799822  0.796769  0.803414
# 4    0.787229  0.787229  0.787229  0.787229  0.787229  0.787229  0.787229
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.980501  0.976199  0.970437  0.965205  0.959823  0.956699  0.935207
# 146  0.109371  0.127367  0.140815  0.134499  0.119198  0.119349  0.131822
# 147  0.434982  0.443362  0.449166  0.437776  0.445506  0.434656  0.433961
# 148  0.639329  0.643643  0.648133  0.649611  0.648682  0.661499  0.653164
# 149  0.095123  0.114558  0.122538  0.110099  0.101100  0.085757  0.088499
#
#             7         8         9  ...    249991    249992    249993  \
# ...

# %%
x = bollywood_actors.values[:,:-1]

# %%
y = bollywood_actors.values[:,-1]

# %%
x
# Out:
# array([[0.8151112492156858, 0.8161457131372547, 0.8185333049019605, ...,
#         0.4935121619607839, 0.49161370213019523, 0.49078134974745125],
#        [0.7985540705964815, 0.7961506342208227, 0.7936856419738316, ...,
#         0.06824894109244636, 0.06744667925009158, 0.06693616649193437],
#        [0.09393331641363442, 0.1703370933831024, 0.16190725119841745,
#         ..., 0.9871986930426473, 0.9871456263294948, 0.9834544083272388],
#        ...,
#        [0.4349815149794889, 0.4433620493252785, 0.44916581837280056, ...,
#         0.36812711501599454, 0.3743432216121177, 0.36377834464420356],
#        [0.639329255796349, 0.6436425720177554, 0.6481328617378409, ...,
#         0.7629458114178059, 0.7595310487092198, 0.7584380434368125],
#        [0.09512315811652428, 0.1145580605514241, 0.12253819102330969,
#         ..., 0.38832310449811647, 0.4648880361221752,
#         0.45009835401461407]], dtype=object)

# %%
y
# Out:
# array(['arm', 'arm', 'arm', 'kajol', 'arm', 'arm', 'kajol', 'kajol',
#        'arm', 'kajol', 'arm', 'arm', 'arm', 'arm', 'arm', 'kajol', 'arm',
#        'kajol', 'kajol', 'kajol', 'kajol', 'arm', 'kajol', 'arm', 'arm',
#        'arm', 'kajol', 'arm', 'kajol', 'kajol', 'arm', 'arm', 'kajol',
#        'arm', 'arm', 'arm', 'kajol', 'arm', 'arm', 'arm', 'arm', 'arm',
#        'arm', 'kajol', 'kajol', 'arm', 'arm', 'arm', 'arm', 'kajol',
#        'arm', 'kajol', 'arm', 'arm', 'arm', 'kajol', 'arm', 'arm', 'arm',
#        'arm', 'kajol', 'arm', 'kajol', 'arm', 'arm', 'arm', 'kajol',
#        'arm', 'arm', 'kajol', 'arm', 'arm', 'arm', 'arm', 'arm', 'arm',
#        'arm', 'kajol', 'arm', 'kajol', 'arm', 'arm', 'kajol', 'kajol',
#        'arm', 'arm', 'arm', 'arm', 'arm', 'kajol', 'arm', 'arm', 'arm',
#        'arm', 'arm', 'kajol', 'arm', 'kajol', 'arm', 'arm', 'kajol',
#        'kajol', 'kajol', 'arm', 'arm', 'arm', 'kajol', 'arm', 'arm',
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf = svm.SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array(['arm', 'kajol', 'arm', 'arm', 'arm', 'arm', 'arm', 'arm', 'arm',
#        'arm', 'arm', 'arm', 'arm', 'arm', 'arm', 'arm', 'arm', 'arm',
#        'arm', 'arm', 'arm', 'arm', 'arm', 'arm', 'arm', 'arm', 'arm',
#        'arm', 'arm', 'arm'], dtype=object)

# %%
from sklearn import metrics

# %%
accuracy = metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.6333333333333333
